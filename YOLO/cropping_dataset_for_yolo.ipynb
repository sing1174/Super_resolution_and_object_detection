# %%
import os
import cv2
import numpy as np
from tqdm import tqdm

def split_and_resize(image_path, label_path, output_image_dir, output_label_dir, target_size=(1024, 1024), padding_threshold=0.3, max_crops=5, max_black_area=0.2):
    os.makedirs(output_image_dir, exist_ok=True)
    os.makedirs(output_label_dir, exist_ok=True)

    image = cv2.imread(image_path)
    h, w, _ = image.shape

    with open(label_path, 'r') as f:
        labels = [line.strip().split() for line in f.readlines()]

    # Convert YOLO normalized labels to pixel-based coordinates
    bbox_list = []
    for label in labels:
        class_id, cx, cy, bw, bh = map(float, label)
        cx, cy, bw, bh = cx * w, cy * h, bw * w, bh * h
        x1, y1 = cx - bw / 2, cy - bh / 2
        x2, y2 = cx + bw / 2, cy + bh / 2
        bbox_list.append((class_id, x1, y1, x2, y2))

    # Calculate stride dynamically to limit the number of crops
    max_stride_x = max(1, (w - target_size[0]) // max_crops)  # Max stride for width
    max_stride_y = max(1, (h - target_size[1]) // max_crops)  # Max stride for height
    stride_x = max(target_size[0] // 2, max_stride_x)
    stride_y = max(target_size[1] // 2, max_stride_y)

    output_count = 0

    for y in range(0, h, stride_y):
        for x in range(0, w, stride_x):
            cropped_image = image[y:y+target_size[1], x:x+target_size[0]]
            crop_h, crop_w, _ = cropped_image.shape

            # If the crop size is smaller than target, pad it
            if crop_h < target_size[1] or crop_w < target_size[0]:
                pad_top = 0
                pad_bottom = target_size[1] - crop_h
                pad_left = 0
                pad_right = target_size[0] - crop_w

                cropped_image = cv2.copyMakeBorder(cropped_image, pad_top, pad_bottom, pad_left, pad_right, cv2.BORDER_CONSTANT, value=(0, 0, 0))

            # Calculate the ratio of non-zero (non-black) area
            # We define black pixels as those with values below a certain threshold (e.g., 30 for RGB channels)
            black_pixels = np.sum(np.all(cropped_image < 30, axis=-1))  # Count pixels that are very dark
            black_area_ratio = black_pixels / (target_size[0] * target_size[1])

            if black_area_ratio > max_black_area:
                continue  # Skip crop if black area exceeds threshold

            # Calculate the ratio of non-zero (non-black) area
            non_zero_ratio = np.count_nonzero(cropped_image) / (target_size[0] * target_size[1] * 3)

            if non_zero_ratio < padding_threshold:
                continue  # Skip crop if non-zero area is below padding threshold

            # Adjust labels for the cropped area
            new_labels = []
            for class_id, x1, y1, x2, y2 in bbox_list:
                if x1 >= x+target_size[0] or x2 <= x or y1 >= y+target_size[1] or y2 <= y:
                    continue  # Skip boxes outside the crop

                nx1 = max(x1 - x, 0)
                ny1 = max(y1 - y, 0)
                nx2 = min(x2 - x, target_size[0])
                ny2 = min(y2 - y, target_size[1])

                # Recalculate normalized values
                ncx = (nx1 + nx2) / 2 / target_size[0]
                ncy = (ny1 + ny2) / 2 / target_size[1]
                nbw = (nx2 - nx1) / target_size[0]
                nbh = (ny2 - ny1) / target_size[1]

                new_labels.append(f"{int(class_id)} {ncx:.6f} {ncy:.6f} {nbw:.6f} {nbh:.6f}")

            if not new_labels:
                continue

            # Save the cropped image and label
            output_image_path = os.path.join(output_image_dir, f"{os.path.basename(image_path).split('.')[0]}_{output_count}.jpg")
            output_label_path = os.path.join(output_label_dir, f"{os.path.basename(label_path).split('.')[0]}_{output_count}.txt")

            cv2.imwrite(output_image_path, cropped_image)
            with open(output_label_path, 'w') as f:
                f.write("\n".join(new_labels))

            output_count += 1
            if output_count >= max_crops:
                return  # Stop once we reach the desired number of crops

# Example usage
input_image_dir = "C:/Users/Asus/Downloads/Computer_vision/Project/validation_dataset/images"
input_label_dir = "C:/Users/Asus/Downloads/Computer_vision/Project/validation_dataset/labels"
output_image_dir = "val_images"
output_label_dir = "val_labels"

image_files = [f for f in os.listdir(input_image_dir) if f.endswith(('.jpg', '.png'))]
label_files = [f.replace('.jpg', '.txt').replace('.png', '.txt') for f in image_files]

for image_file, label_file in tqdm(zip(image_files, label_files), total=len(image_files)):
    split_and_resize(
        os.path.join(input_image_dir, image_file),
        os.path.join(input_label_dir, label_file),
        output_image_dir,
        output_label_dir,
        max_crops=5 # Set the maximum number of crops per image
    )
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 458/458 [01:47<00:00,  4.25it/s]

# %% [markdown]
# # Viewing the label on images

# %%
import os
import cv2
import numpy as np

image_folder = 'yolo_dataset/train/images'
label_folder = 'yolo_dataset/train/labels'
output_folder = 'labels_on_images'

os.makedirs(output_folder, exist_ok=True)

def draw_yolo_labels(image, label_file):
    with open(label_file, 'r') as f:
        labels = f.readlines()

    for label in labels:
        
        parts = label.strip().split()
        class_id = int(parts[0])
        x_center = float(parts[1])
        y_center = float(parts[2])
        width = float(parts[3])
        height = float(parts[4])

        
        img_height, img_width = image.shape[:2]

        
        x_center_pixel = int(x_center * img_width)
        y_center_pixel = int(y_center * img_height)
        width_pixel = int(width * img_width)
        height_pixel = int(height * img_height)

        
        top_left_x = int(x_center_pixel - width_pixel / 2)
        top_left_y = int(y_center_pixel - height_pixel / 2)
        bottom_right_x = int(x_center_pixel + width_pixel / 2)
        bottom_right_y = int(y_center_pixel + height_pixel / 2)

        
        color = (0, 255, 0) 
        thickness = 2  
        cv2.rectangle(image, (top_left_x, top_left_y), (bottom_right_x, bottom_right_y), color, thickness)

    return image

for image_name in os.listdir(image_folder):
    
    if image_name.lower().endswith(('.jpg', '.jpeg', '.png')):
        image_path = os.path.join(image_folder, image_name)
        label_path = os.path.join(label_folder, image_name.replace('.jpg', '.txt').replace('.jpeg', '.txt').replace('.png', '.txt'))

        if os.path.exists(label_path):
            
            image = cv2.imread(image_path)

            annotated_image = draw_yolo_labels(image, label_path)

            output_image_path = os.path.join(output_folder, image_name)
            cv2.imwrite(output_image_path, annotated_image)
            print(f"Processed and saved: {output_image_path}")
        else:
            print(f"Label file missing for image: {image_name}")
# Out:
# Processed and saved: labels_on_images\P0000_0.jpg
# Processed and saved: labels_on_images\P0000_1.jpg
# Processed and saved: labels_on_images\P0000_2.jpg
# Processed and saved: labels_on_images\P0000_3.jpg
# Processed and saved: labels_on_images\P0000_4.jpg
# Processed and saved: labels_on_images\P0001_0.jpg
# Processed and saved: labels_on_images\P0001_1.jpg
# Processed and saved: labels_on_images\P0001_2.jpg
# Processed and saved: labels_on_images\P0002_0.jpg
# Processed and saved: labels_on_images\P0002_1.jpg
# Processed and saved: labels_on_images\P0002_2.jpg
# Processed and saved: labels_on_images\P0002_3.jpg
# Processed and saved: labels_on_images\P0002_4.jpg
# Processed and saved: labels_on_images\P0008_0.jpg
# Processed and saved: labels_on_images\P0010_0.jpg
# Processed and saved: labels_on_images\P0010_1.jpg
# Processed and saved: labels_on_images\P0010_2.jpg
# Processed and saved: labels_on_images\P0010_3.jpg
# Processed and saved: labels_on_images\P0011_0.jpg
# Processed and saved: labels_on_images\P0011_1.jpg
# Processed and saved: labels_on_images\P0012_0.jpg
# Processed and saved: labels_on_images\P0012_1.jpg
# Processed and saved: labels_on_images\P0012_2.jpg
# Processed and saved: labels_on_images\P0012_3.jpg
# Processed and saved: labels_on_images\P0012_4.jpg
# Processed and saved: labels_on_images\P0013_0.jpg
# Processed and saved: labels_on_images\P0013_1.jpg
# Processed and saved: labels_on_images\P0018_0.jpg
# Processed and saved: labels_on_images\P0018_1.jpg
# Processed and saved: labels_on_images\P0018_2.jpg
# Processed and saved: labels_on_images\P0020_0.jpg
# Processed and saved: labels_on_images\P0020_1.jpg
# Processed and saved: labels_on_images\P0020_2.jpg
# Processed and saved: labels_on_images\P0020_3.jpg
# Processed and saved: labels_on_images\P0020_4.jpg
# Processed and saved: labels_on_images\P0021_0.jpg
# Processed and saved: labels_on_images\P0021_1.jpg
# Processed and saved: labels_on_images\P0021_2.jpg
# Processed and saved: labels_on_images\P0021_3.jpg
# Processed and saved: labels_on_images\P0021_4.jpg
# Processed and saved: labels_on_images\P0022_0.jpg
# Processed and saved: labels_on_images\P0022_1.jpg
# Processed and saved: labels_on_images\P0022_2.jpg
# Processed and saved: labels_on_images\P0022_3.jpg
# Processed and saved: labels_on_images\P0022_4.jpg
# Processed and saved: labels_on_images\P0023_0.jpg
# Processed and saved: labels_on_images\P0023_1.jpg
# Processed and saved: labels_on_images\P0023_2.jpg
# Processed and saved: labels_on_images\P0023_3.jpg
# Processed and saved: labels_on_images\P0023_4.jpg
# Processed and saved: labels_on_images\P0025_0.jpg
# Processed and saved: labels_on_images\P0029_0.jpg
# Processed and saved: labels_on_images\P0029_1.jpg
# Processed and saved: labels_on_images\P0029_2.jpg
# Processed and saved: labels_on_images\P0029_3.jpg
# Processed and saved: labels_on_images\P0029_4.jpg
# Processed and saved: labels_on_images\P0030_0.jpg
# Processed and saved: labels_on_images\P0030_1.jpg
# Processed and saved: labels_on_images\P0030_2.jpg
# Processed and saved: labels_on_images\P0030_3.jpg
# Processed and saved: labels_on_images\P0030_4.jpg
# Processed and saved: labels_on_images\P0032_0.jpg
# Processed and saved: labels_on_images\P0032_1.jpg
# Processed and saved: labels_on_images\P0032_2.jpg
# Processed and saved: labels_on_images\P0032_3.jpg
# Processed and saved: labels_on_images\P0032_4.jpg
# Processed and saved: labels_on_images\P0036_0.jpg
# Processed and saved: labels_on_images\P0036_1.jpg
# Processed and saved: labels_on_images\P0036_2.jpg
# Processed and saved: labels_on_images\P0036_3.jpg
# Processed and saved: labels_on_images\P0036_4.jpg
# Processed and saved: labels_on_images\P0038_0.jpg
# Processed and saved: labels_on_images\P0038_1.jpg
# Processed and saved: labels_on_images\P0038_2.jpg
# Processed and saved: labels_on_images\P0038_3.jpg
# Processed and saved: labels_on_images\P0038_4.jpg
# Processed and saved: labels_on_images\P0039_0.jpg
# Processed and saved: labels_on_images\P0039_1.jpg
# Processed and saved: labels_on_images\P0039_2.jpg
# Processed and saved: labels_on_images\P0039_3.jpg
# Processed and saved: labels_on_images\P0039_4.jpg
# Processed and saved: labels_on_images\P0041_0.jpg
# Processed and saved: labels_on_images\P0041_1.jpg
# Processed and saved: labels_on_images\P0041_2.jpg
# Processed and saved: labels_on_images\P0041_3.jpg
# Processed and saved: labels_on_images\P0041_4.jpg
# Processed and saved: labels_on_images\P0042_0.jpg
# Processed and saved: labels_on_images\P0042_1.jpg
# Processed and saved: labels_on_images\P0042_2.jpg
# Processed and saved: labels_on_images\P0042_3.jpg
# Processed and saved: labels_on_images\P0042_4.jpg
# Processed and saved: labels_on_images\P0049_0.jpg
# Processed and saved: labels_on_images\P0049_1.jpg
# Processed and saved: labels_on_images\P0049_2.jpg
# Processed and saved: labels_on_images\P0049_3.jpg
# Processed and saved: labels_on_images\P0052_0.jpg
# Processed and saved: labels_on_images\P0052_1.jpg
# Processed and saved: labels_on_images\P0052_2.jpg
# Processed and saved: labels_on_images\P0054_0.jpg
# Processed and saved: labels_on_images\P0054_1.jpg
# Processed and saved: labels_on_images\P0054_2.jpg
# Processed and saved: labels_on_images\P0054_3.jpg
# Processed and saved: labels_on_images\P0054_4.jpg
# Processed and saved: labels_on_images\P0058_0.jpg
# Processed and saved: labels_on_images\P0061_0.jpg
# Processed and saved: labels_on_images\P0061_1.jpg
# Processed and saved: labels_on_images\P0061_2.jpg
# Processed and saved: labels_on_images\P0061_3.jpg
# Processed and saved: labels_on_images\P0061_4.jpg
# Processed and saved: labels_on_images\P0063_0.jpg
# Processed and saved: labels_on_images\P0063_1.jpg
# Processed and saved: labels_on_images\P0063_2.jpg
# Processed and saved: labels_on_images\P0063_3.jpg
# Processed and saved: labels_on_images\P0063_4.jpg
# Processed and saved: labels_on_images\P0064_0.jpg
# Processed and saved: labels_on_images\P0064_1.jpg
# Processed and saved: labels_on_images\P0064_2.jpg
# Processed and saved: labels_on_images\P0064_3.jpg
# Processed and saved: labels_on_images\P0064_4.jpg
# Processed and saved: labels_on_images\P0065_0.jpg
# Processed and saved: labels_on_images\P0065_1.jpg
# Processed and saved: labels_on_images\P0065_2.jpg
# Processed and saved: labels_on_images\P0065_3.jpg
# Processed and saved: labels_on_images\P0065_4.jpg
# Processed and saved: labels_on_images\P0066_0.jpg
# Processed and saved: labels_on_images\P0066_1.jpg
# Processed and saved: labels_on_images\P0066_2.jpg
# Processed and saved: labels_on_images\P0066_3.jpg
# Processed and saved: labels_on_images\P0066_4.jpg
# Processed and saved: labels_on_images\P0067_0.jpg
# Processed and saved: labels_on_images\P0067_1.jpg
# Processed and saved: labels_on_images\P0070_0.jpg
# Processed and saved: labels_on_images\P0082_0.jpg
# Processed and saved: labels_on_images\P0082_1.jpg
# Processed and saved: labels_on_images\P0082_2.jpg
# Processed and saved: labels_on_images\P0082_3.jpg
# Processed and saved: labels_on_images\P0082_4.jpg
# Processed and saved: labels_on_images\P0083_0.jpg
# Processed and saved: labels_on_images\P0083_1.jpg
# Processed and saved: labels_on_images\P0083_2.jpg
# Processed and saved: labels_on_images\P0083_3.jpg
# Processed and saved: labels_on_images\P0083_4.jpg
# Processed and saved: labels_on_images\P0085_0.jpg
# Processed and saved: labels_on_images\P0085_1.jpg
# Processed and saved: labels_on_images\P0085_2.jpg
# Processed and saved: labels_on_images\P0085_3.jpg
# Processed and saved: labels_on_images\P0085_4.jpg
# Processed and saved: labels_on_images\P0087_0.jpg
# Processed and saved: labels_on_images\P0087_1.jpg
# Processed and saved: labels_on_images\P0087_2.jpg
# Processed and saved: labels_on_images\P0087_3.jpg
# Processed and saved: labels_on_images\P0087_4.jpg
# Processed and saved: labels_on_images\P0094_0.jpg
# Processed and saved: labels_on_images\P0095_0.jpg
# Processed and saved: labels_on_images\P0098_0.jpg
# Processed and saved: labels_on_images\P0099_0.jpg
# Processed and saved: labels_on_images\P0099_1.jpg
# Processed and saved: labels_on_images\P0109_0.jpg
# Processed and saved: labels_on_images\P0111_0.jpg
# Processed and saved: labels_on_images\P0111_1.jpg
# Processed and saved: labels_on_images\P0111_2.jpg
# Processed and saved: labels_on_images\P0111_3.jpg
# Processed and saved: labels_on_images\P0113_0.jpg
# Processed and saved: labels_on_images\P0113_1.jpg
# Processed and saved: labels_on_images\P0113_2.jpg
# Processed and saved: labels_on_images\P0113_3.jpg
# Processed and saved: labels_on_images\P0113_4.jpg
# Processed and saved: labels_on_images\P0119_0.jpg
# Processed and saved: labels_on_images\P0119_1.jpg
# Processed and saved: labels_on_images\P0119_2.jpg
# Processed and saved: labels_on_images\P0119_3.jpg
# Processed and saved: labels_on_images\P0119_4.jpg
# Processed and saved: labels_on_images\P0122_0.jpg
# Processed and saved: labels_on_images\P0122_1.jpg
# Processed and saved: labels_on_images\P0122_2.jpg
# Processed and saved: labels_on_images\P0122_3.jpg
# Processed and saved: labels_on_images\P0124_0.jpg
# Processed and saved: labels_on_images\P0124_1.jpg
# Processed and saved: labels_on_images\P0124_2.jpg
# Processed and saved: labels_on_images\P0124_3.jpg
# Processed and saved: labels_on_images\P0124_4.jpg
# Processed and saved: labels_on_images\P0129_0.jpg
# Processed and saved: labels_on_images\P0129_1.jpg
# Processed and saved: labels_on_images\P0129_2.jpg
# Processed and saved: labels_on_images\P0129_3.jpg
# Processed and saved: labels_on_images\P0129_4.jpg
# Processed and saved: labels_on_images\P0133_0.jpg
# Processed and saved: labels_on_images\P0136_0.jpg
# Processed and saved: labels_on_images\P0136_1.jpg
# Processed and saved: labels_on_images\P0136_2.jpg
# Processed and saved: labels_on_images\P0136_3.jpg
# Processed and saved: labels_on_images\P0136_4.jpg
# Processed and saved: labels_on_images\P0141_0.jpg
# Processed and saved: labels_on_images\P0141_1.jpg
# Processed and saved: labels_on_images\P0141_2.jpg
# Processed and saved: labels_on_images\P0141_3.jpg
# Processed and saved: labels_on_images\P0141_4.jpg
# Processed and saved: labels_on_images\P0158_0.jpg
# Processed and saved: labels_on_images\P0158_1.jpg
# Processed and saved: labels_on_images\P0158_2.jpg
# Processed and saved: labels_on_images\P0158_3.jpg
# Processed and saved: labels_on_images\P0158_4.jpg
# Processed and saved: labels_on_images\P0160_0.jpg
# Processed and saved: labels_on_images\P0160_1.jpg
# Processed and saved: labels_on_images\P0160_2.jpg
# Processed and saved: labels_on_images\P0160_3.jpg
# Processed and saved: labels_on_images\P0160_4.jpg
# Processed and saved: labels_on_images\P0162_0.jpg
# Processed and saved: labels_on_images\P0162_1.jpg
# Processed and saved: labels_on_images\P0167_0.jpg
# Processed and saved: labels_on_images\P0167_1.jpg
# Processed and saved: labels_on_images\P0167_2.jpg
# Processed and saved: labels_on_images\P0167_3.jpg
# Processed and saved: labels_on_images\P0167_4.jpg
# Processed and saved: labels_on_images\P0169_0.jpg
# Processed and saved: labels_on_images\P0169_1.jpg
# Processed and saved: labels_on_images\P0169_2.jpg
# Processed and saved: labels_on_images\P0169_3.jpg
# Processed and saved: labels_on_images\P0169_4.jpg
# Processed and saved: labels_on_images\P0171_0.jpg
# Processed and saved: labels_on_images\P0171_1.jpg
# Processed and saved: labels_on_images\P0171_2.jpg
# Processed and saved: labels_on_images\P0171_3.jpg
# Processed and saved: labels_on_images\P0171_4.jpg
# Processed and saved: labels_on_images\P0172_0.jpg
# Processed and saved: labels_on_images\P0172_1.jpg
# Processed and saved: labels_on_images\P0172_2.jpg
# Processed and saved: labels_on_images\P0172_3.jpg
# Processed and saved: labels_on_images\P0172_4.jpg
# Processed and saved: labels_on_images\P0174_0.jpg
# Processed and saved: labels_on_images\P0174_1.jpg
# Processed and saved: labels_on_images\P0174_2.jpg
# Processed and saved: labels_on_images\P0174_3.jpg
# Processed and saved: labels_on_images\P0174_4.jpg
# Processed and saved: labels_on_images\P0178_0.jpg
# Processed and saved: labels_on_images\P0178_1.jpg
# Processed and saved: labels_on_images\P0178_2.jpg
# Processed and saved: labels_on_images\P0178_3.jpg
# Processed and saved: labels_on_images\P0178_4.jpg
# Processed and saved: labels_on_images\P0183_0.jpg
# Processed and saved: labels_on_images\P0183_1.jpg
# Processed and saved: labels_on_images\P0183_2.jpg
# Processed and saved: labels_on_images\P0183_3.jpg
# Processed and saved: labels_on_images\P0183_4.jpg
# Processed and saved: labels_on_images\P0187_0.jpg
# Processed and saved: labels_on_images\P0187_1.jpg
# Processed and saved: labels_on_images\P0187_2.jpg
# Processed and saved: labels_on_images\P0187_3.jpg
# Processed and saved: labels_on_images\P0187_4.jpg
# Processed and saved: labels_on_images\P0188_0.jpg
# Processed and saved: labels_on_images\P0188_1.jpg
# Processed and saved: labels_on_images\P0188_2.jpg
# Processed and saved: labels_on_images\P0188_3.jpg
# Processed and saved: labels_on_images\P0188_4.jpg
# Processed and saved: labels_on_images\P0190_0.jpg
# Processed and saved: labels_on_images\P0190_1.jpg
# Processed and saved: labels_on_images\P0190_2.jpg
# Processed and saved: labels_on_images\P0190_3.jpg
# Processed and saved: labels_on_images\P0190_4.jpg
# Processed and saved: labels_on_images\P0201_0.jpg
# Processed and saved: labels_on_images\P0202_0.jpg
# Processed and saved: labels_on_images\P0207_0.jpg
# Processed and saved: labels_on_images\P0209_0.jpg
# Processed and saved: labels_on_images\P0209_1.jpg
# Processed and saved: labels_on_images\P0209_2.jpg
# Processed and saved: labels_on_images\P0209_3.jpg
# Processed and saved: labels_on_images\P0209_4.jpg
# Processed and saved: labels_on_images\P0210_0.jpg
# Processed and saved: labels_on_images\P0210_1.jpg
# Processed and saved: labels_on_images\P0210_2.jpg
# Processed and saved: labels_on_images\P0210_3.jpg
# Processed and saved: labels_on_images\P0215_0.jpg
# Processed and saved: labels_on_images\P0215_1.jpg
# Processed and saved: labels_on_images\P0215_2.jpg
# Processed and saved: labels_on_images\P0215_3.jpg
# Processed and saved: labels_on_images\P0215_4.jpg
# Processed and saved: labels_on_images\P0218_0.jpg
# Processed and saved: labels_on_images\P0218_1.jpg
# Processed and saved: labels_on_images\P0218_2.jpg
# Processed and saved: labels_on_images\P0218_3.jpg
# Processed and saved: labels_on_images\P0218_4.jpg
# Processed and saved: labels_on_images\P0219_0.jpg
# Processed and saved: labels_on_images\P0219_1.jpg
# Processed and saved: labels_on_images\P0219_2.jpg
# Processed and saved: labels_on_images\P0219_3.jpg
# Processed and saved: labels_on_images\P0220_0.jpg
# Processed and saved: labels_on_images\P0220_1.jpg
# Processed and saved: labels_on_images\P0220_2.jpg
# Processed and saved: labels_on_images\P0221_0.jpg
# Processed and saved: labels_on_images\P0221_1.jpg
# Processed and saved: labels_on_images\P0221_2.jpg
# Processed and saved: labels_on_images\P0221_3.jpg
# Processed and saved: labels_on_images\P0221_4.jpg
# Processed and saved: labels_on_images\P0222_0.jpg
# Processed and saved: labels_on_images\P0222_1.jpg
# Processed and saved: labels_on_images\P0222_2.jpg
# Processed and saved: labels_on_images\P0222_3.jpg
# Processed and saved: labels_on_images\P0223_0.jpg
# Processed and saved: labels_on_images\P0223_1.jpg
# Processed and saved: labels_on_images\P0223_2.jpg
# Processed and saved: labels_on_images\P0223_3.jpg
# Processed and saved: labels_on_images\P0224_0.jpg
# Processed and saved: labels_on_images\P0225_0.jpg
# Processed and saved: labels_on_images\P0227_0.jpg
# Processed and saved: labels_on_images\P0229_0.jpg
# Processed and saved: labels_on_images\P0229_1.jpg
# Processed and saved: labels_on_images\P0232_0.jpg
# Processed and saved: labels_on_images\P0232_1.jpg
# Processed and saved: labels_on_images\P0232_2.jpg
# Processed and saved: labels_on_images\P0232_3.jpg
# Processed and saved: labels_on_images\P0233_0.jpg
# Processed and saved: labels_on_images\P0235_0.jpg
# Processed and saved: labels_on_images\P0235_1.jpg
# Processed and saved: labels_on_images\P0236_0.jpg
# Processed and saved: labels_on_images\P0236_1.jpg
# Processed and saved: labels_on_images\P0238_0.jpg
# Processed and saved: labels_on_images\P0241_0.jpg
# Processed and saved: labels_on_images\P0244_0.jpg
# Processed and saved: labels_on_images\P0250_0.jpg
# Processed and saved: labels_on_images\P0250_1.jpg
# Processed and saved: labels_on_images\P0250_2.jpg
# Processed and saved: labels_on_images\P0251_0.jpg
# Processed and saved: labels_on_images\P0251_1.jpg
# Processed and saved: labels_on_images\P0251_2.jpg
# Processed and saved: labels_on_images\P0251_3.jpg
# Processed and saved: labels_on_images\P0251_4.jpg
# Processed and saved: labels_on_images\P0252_0.jpg
# Processed and saved: labels_on_images\P0252_1.jpg
# Processed and saved: labels_on_images\P0254_0.jpg
# Processed and saved: labels_on_images\P0254_1.jpg
# Processed and saved: labels_on_images\P0254_2.jpg
# Processed and saved: labels_on_images\P0254_3.jpg
# Processed and saved: labels_on_images\P0254_4.jpg
# Processed and saved: labels_on_images\P0255_0.jpg
# Processed and saved: labels_on_images\P0255_1.jpg
# Processed and saved: labels_on_images\P0255_2.jpg
# Processed and saved: labels_on_images\P0256_0.jpg
# Processed and saved: labels_on_images\P0258_0.jpg
# Processed and saved: labels_on_images\P0260_0.jpg
# Processed and saved: labels_on_images\P0260_1.jpg
# Processed and saved: labels_on_images\P0260_2.jpg
# Processed and saved: labels_on_images\P0260_3.jpg
# Processed and saved: labels_on_images\P0270_0.jpg
# Processed and saved: labels_on_images\P0270_1.jpg
# Processed and saved: labels_on_images\P0273_0.jpg
# Processed and saved: labels_on_images\P0273_1.jpg
# Processed and saved: labels_on_images\P0275_0.jpg
# Processed and saved: labels_on_images\P0276_0.jpg
# Processed and saved: labels_on_images\P0276_1.jpg
# Processed and saved: labels_on_images\P0282_0.jpg
# Processed and saved: labels_on_images\P0288_0.jpg
# Processed and saved: labels_on_images\P0289_0.jpg
# Processed and saved: labels_on_images\P0292_0.jpg
# Processed and saved: labels_on_images\P0293_0.jpg
# Processed and saved: labels_on_images\P0293_1.jpg
# Processed and saved: labels_on_images\P0294_0.jpg
# Processed and saved: labels_on_images\P0294_1.jpg
# Processed and saved: labels_on_images\P0296_0.jpg
# Processed and saved: labels_on_images\P0308_0.jpg
# Processed and saved: labels_on_images\P0308_1.jpg
# Processed and saved: labels_on_images\P0310_0.jpg
# Processed and saved: labels_on_images\P0310_1.jpg
# Processed and saved: labels_on_images\P0310_2.jpg
# Processed and saved: labels_on_images\P0310_3.jpg
# Processed and saved: labels_on_images\P0310_4.jpg
# Processed and saved: labels_on_images\P0313_0.jpg
# Processed and saved: labels_on_images\P0313_1.jpg
# Processed and saved: labels_on_images\P0314_0.jpg
# Processed and saved: labels_on_images\P0314_1.jpg
# Processed and saved: labels_on_images\P0315_0.jpg
# Processed and saved: labels_on_images\P0317_0.jpg
# Processed and saved: labels_on_images\P0317_1.jpg
# Processed and saved: labels_on_images\P0317_2.jpg
# Processed and saved: labels_on_images\P0321_0.jpg
# Processed and saved: labels_on_images\P0321_1.jpg
# Processed and saved: labels_on_images\P0321_2.jpg
# Processed and saved: labels_on_images\P0321_3.jpg
# Processed and saved: labels_on_images\P0321_4.jpg
# Processed and saved: labels_on_images\P0322_0.jpg
# Processed and saved: labels_on_images\P0322_1.jpg
# Processed and saved: labels_on_images\P0322_2.jpg
# Processed and saved: labels_on_images\P0322_3.jpg
# Processed and saved: labels_on_images\P0322_4.jpg
# Processed and saved: labels_on_images\P0324_0.jpg
# Processed and saved: labels_on_images\P0324_1.jpg
# Processed and saved: labels_on_images\P0327_0.jpg
# Processed and saved: labels_on_images\P0327_1.jpg
# Processed and saved: labels_on_images\P0327_2.jpg
# Processed and saved: labels_on_images\P0327_3.jpg
# Processed and saved: labels_on_images\P0327_4.jpg
# Processed and saved: labels_on_images\P0330_0.jpg
# Processed and saved: labels_on_images\P0332_0.jpg
# Processed and saved: labels_on_images\P0332_1.jpg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 59
#      56     annotated_image = draw_yolo_labels(image, label_path)
#      58     output_image_path = os.path.join(output_folder, image_name)
# ---> 59     cv2.imwrite(output_image_path, annotated_image)
#      60     print(f"Processed and saved: {output_image_path}")
#      61 else:
#
# KeyboardInterrupt:

# %% [markdown]
# # Below is to randomly distribute dataset

# %%
import os
import random
import shutil

# Paths to the image and label folders
image_folder = "train_images"
label_folder = "train_labels"

# Output folder structure
yolo_dataset = "yolo_dataset"
train_folder = os.path.join(yolo_dataset, "train")
val_folder = os.path.join(yolo_dataset, "val")

# Create the necessary directories
os.makedirs(train_folder, exist_ok=True)
os.makedirs(val_folder, exist_ok=True)
os.makedirs(os.path.join(train_folder, "images"), exist_ok=True)
os.makedirs(os.path.join(train_folder, "labels"), exist_ok=True)
os.makedirs(os.path.join(val_folder, "images"), exist_ok=True)
os.makedirs(os.path.join(val_folder, "labels"), exist_ok=True)

# Get list of image and label files
image_files = sorted(os.listdir(image_folder))
label_files = sorted(os.listdir(label_folder))

# Ensure there is a 1:1 correspondence between image and label files
assert len(image_files) == len(label_files), "Number of images and labels must match."

# Randomly shuffle the indices to split the data
indices = list(range(len(image_files)))
random.shuffle(indices)

# Define the split ratio (80% for training, 20% for validation)
split_ratio = 0.8
train_indices = indices[:int(len(indices) * split_ratio)]
val_indices = indices[int(len(indices) * split_ratio):]

# Function to copy files
def copy_files(indices, source_image_folder, source_label_folder, target_image_folder, target_label_folder):
    for idx in indices:
        # Get the corresponding image and label filenames
        image_file = image_files[idx]
        label_file = label_files[idx]
        
        # Construct the source and destination paths
        image_source = os.path.join(source_image_folder, image_file)
        label_source = os.path.join(source_label_folder, label_file)
        
        image_dest = os.path.join(target_image_folder, image_file)
        label_dest = os.path.join(target_label_folder, label_file)
        
        # Copy the files
        shutil.copy(image_source, image_dest)
        shutil.copy(label_source, label_dest)

# Copy the files to the "train" and "val" folders
copy_files(train_indices, image_folder, label_folder, os.path.join(train_folder, "images"), os.path.join(train_folder, "labels"))
copy_files(val_indices, image_folder, label_folder, os.path.join(val_folder, "images"), os.path.join(val_folder, "labels"))

print("Dataset has been split into 'train' and 'val' folders.")
# Out:
# Dataset has been split into 'train' and 'val' folders.

# %% [markdown]
# # Code to crop images only

# %%
import os
import cv2
import numpy as np
from tqdm import tqdm

def split_and_resize(image_path, output_image_dir, target_size=(1024, 1024), padding_threshold=0.3, max_crops=5, max_black_area=0.2):
    os.makedirs(output_image_dir, exist_ok=True)

    image = cv2.imread(image_path)
    h, w, _ = image.shape

    # Calculate stride dynamically to limit the number of crops
    max_stride_x = max(1, (w - target_size[0]) // max_crops)  # Max stride for width
    max_stride_y = max(1, (h - target_size[1]) // max_crops)  # Max stride for height
    stride_x = max(target_size[0] // 2, max_stride_x)
    stride_y = max(target_size[1] // 2, max_stride_y)

    output_count = 0

    for y in range(0, h, stride_y):
        for x in range(0, w, stride_x):
            cropped_image = image[y:y+target_size[1], x:x+target_size[0]]
            crop_h, crop_w, _ = cropped_image.shape

            # If the crop size is smaller than target, pad it
            if crop_h < target_size[1] or crop_w < target_size[0]:
                pad_top = 0
                pad_bottom = target_size[1] - crop_h
                pad_left = 0
                pad_right = target_size[0] - crop_w

                cropped_image = cv2.copyMakeBorder(cropped_image, pad_top, pad_bottom, pad_left, pad_right, cv2.BORDER_CONSTANT, value=(0, 0, 0))

            # Calculate the ratio of non-zero (non-black) area
            black_pixels = np.sum(np.all(cropped_image < 30, axis=-1))  # Count pixels that are very dark
            black_area_ratio = black_pixels / (target_size[0] * target_size[1])

            if black_area_ratio > max_black_area:
                continue  # Skip crop if black area exceeds threshold

            # Calculate the ratio of non-zero (non-black) area
            non_zero_ratio = np.count_nonzero(cropped_image) / (target_size[0] * target_size[1] * 3)

            if non_zero_ratio < padding_threshold:
                continue  # Skip crop if non-zero area is below padding threshold

            # Save the cropped image
            output_image_path = os.path.join(output_image_dir, f"{os.path.basename(image_path).split('.')[0]}_{output_count}.jpg")
            cv2.imwrite(output_image_path, cropped_image)

            output_count += 1
            if output_count >= max_crops:
                return  # Stop once we reach the desired number of crops

# Example usage
input_image_dir = "C:/Users/Asus/Downloads/Computer_vision/Project_2/test_images"
output_image_dir = "test_images_crop"

image_files = [f for f in os.listdir(input_image_dir) if f.endswith(('.jpg', '.png'))]

for image_file in tqdm(image_files, total=len(image_files)):
    split_and_resize(
        os.path.join(input_image_dir, image_file),
        output_image_dir,
        max_crops=5  # Set the maximum number of crops per image
    )
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 469/469 [02:05<00:00,  3.75it/s]
